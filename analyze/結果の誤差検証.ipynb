# %% [markdown]
# # 各結果を二乗和平方根からαβがどれほど近づいたのか求める

# %%
alpha = [2, 2, 2, 2, 2, 27, 5, 0, 0, 1, 0, 0, 1, 0, 0]

beta = [5, 5, 5, 5, 5, 30, 8, 1, 0, 3, 0, 1, 2, 0, 0]

# %%
import math

# %%
def calc(alpha,calpha,beta,cbeta):
    sum = 0
    
    for i in range(len(alpha)):
        sum += math.sqrt((calpha[i]- alpha[i])**2)
    for i in range(len(beta)):
        sum += math.sqrt((cbeta[i] - beta[i])**2)
    return sum

# %%
# 回答
calpha = [
     [ 1.6, 1.5, 1.9, 1.4, 1.8, 19.9, 6.5, 0.7, 0, 1.7, 0.7, 1.7, 1.2, 0.2, 0.3 ], # 6
     [ 1.7, 1.1, 1.8, 1.3, 1.1, 23.7, 4.1, 0.2, 0, 1.3, 0.3, 0.5, 0.4, 0.1, 0.1 ], # 7
     [ 0.9, 0.7, 0.8, 0.9, 1, 17.9, 1.8, 0, 0, 0.4, 0.1, 0.3, 0.4, 0.1, 0.1 ], #8
     [ 1, 1.4, 1.6, 1, 1.6, 18.4, 2, 0.3, 0, 0.6, 0.3, 0.2, 0.6, 0.1, 0.1 ], #9
    [ 1.9, 2, 1.9, 2.4, 1.9, 294.8, 116.8, 4.6, 0.8, 24.7, 13.8, 20, 18.8, 2.8, 4.7 ], #10
    [ 1.1, 1.5, 0.9, 1.3, 1.1, 216.3, 72.7, 5.2, 0.3, 20.6, 5.3, 7.8, 9.2, 1.7, 2.5 ], # 11
    [ 0.9, 0.8, 0.8, 0.9, 0.7, 326.9, 37.8, 0.6, 0.2, 6.6, 2.3, 3, 3.9, 0.7, 1.2 ], # 12
    [ 0.9, 0.8, 0.8, 0.9, 0.7, 326.9, 37.8, 0.6, 0.2, 6.6, 2.3, 3, 3.9, 0.7, 1.2 ], # 13
    [ 2.3, 1.9, 1.9, 2.3, 1.5, 941.7, 245.4, 21.2, 1.3, 107.9, 36, 44.2, 38.3, 9.1, 17.6 ], # 14
    [ 1.6, 1.5, 1.5, 1.6, 1.4, 996.5, 205.8, 12.3, 0.8, 49.7, 16.5, 15.8, 29.3, 4.9, 11.4 ], # 15
    [ 1, 0.6, 0.5, 1.1, 0.6, 680.6, 88.1, 1.6, 0.4, 24, 7.5, 13.3, 12.7, 2.4, 5.1 ], # 16
    [ 2.6, 1.9, 1.2, 1.4, 0.9, 556.7, 274.2, 21.8, 0.7, 65.3, 7.4, 47.7, 24.7, 5.8, 2.5 ] # 17
    
    
]

cbeta = [
    [ 3.7, 4.1, 4.3, 4.1, 3.8, 42, 11.9, 1.5, 0.1, 4.1, 1.2, 3.3, 3, 0.3, 1 ], # 6
    [ 3.8, 2.3, 3.8, 2.6, 2.8, 37.8, 9.1, 0.7, 0, 2.9, 0.7, 1.3, 1.7, 0.2, 0.4 ], # 7 
    [ 2.9, 1.8, 1.8, 1.9, 1.5, 53.6, 3.7, 0.1, 0, 1, 0.4, 0.5, 0.8, 0.1, 0.2 ],  # 8
    [84, 9329.400031174375, 74.18895718213724, 84, 84, 1134, 125.38671600700351, 0, 0, 42, 0, 0, 42, 1.0490802033307907, 0],
    [100.33942634398292, 84, 84, 84, 84, 825.2546028817535, 136.07788462739114, 0, 0, 56.69756076265957, 0, 0.5745467712355582, 42, 0.8827781087794637, 0],
    [84, 84, 84, 84, 84, 1122.6002999224268, 210, 0.6928627843088876, 0, 33.20539491203275, 0, 0, 42, 0, 0.869066776654309]
]

dbeta = [
    [5.28396397844716, 3.4468810364019293, 5, 5, 5, 30, 8, 1.0594326634204851, 0, 3, 0.8452041525596488, 1, 2, 0, 0],
    [5, 6.360165226280701, 5, 5, 5, 30, 8, 0.9394121386891818, 0, 3, 0, 1, 2, 0, 0],
    [5, 5, 5, 5.218229958173657, 4.954405528121245, 30, 8.683513233572242, 1, 0, 2.8279866781881107, 0, 1, 2.569608308959553, 0, 0],
    [5, 6.26940665299138, 5, 5, 5, 40.862427593816534, 8, 1, 0, 3.52412124939403, 0.8569254584362606, 1, 2.1584453492022635, 0, 0],
    [70, 63.09475604083506, 50.98205503614826, 70, 70, 355.6756911269172, 112, 10.99953540446927, 0, 42, 1.2513581212352718, 14, 28, 0.7207447029671411, 0],
    [70, 70, 70, 70, 83.92233810336329, 420, 112, 14, 0.9685455585689502, 42, 0, 14, 28, 0, 0],
    [70, 51.79357612159113, 70, 70, 70, 441.8675508989214, 79.43584572258217, 10.427771874637305, 1.1765849414769343, 42, 0, 13.950217203902216, 20.44772667313472, 0, 0],
    [70, 65.28910614351793, 70, 70, 70, 421.48686957921274, 84.68566580438952, 14, 0, 42, 0, 11.390961700935787, 14.578694277735545, 0, 0],
    [172.0353154305991, 259.4664687348303, 102.89632696764609, 223.45726767280343, 210, 1260, 306.27008532198147, 31.430399786124664, 1.1893157338883291, 126, 0, 42, 84, 0, 0],
    [210, 9459.014727571626, 276.8970597885764, 210, 210, 1260, 246.7175040152752, 42, 0, 126, 0, 42, 84, 1.1017607959886049, 0],
    [117.58322005423784, 210, 210, 210, 210, 1490.7087775481027, 250.7252123153303, 42, 0, 64.11420776204072, 0, 45.042998927045076, 84, 1.0650430744624781, 0],
    [210, 210, 210, 210, 210, 1145.1638616183127, 336, 30.68654079347223, 0, 163.10228363394182, 0, 42, 84, 0, 0.9666001170139014]
]

# %%
mag_list = [1,14,42]

for i in range(len(calpha)):
    mag = mag_list[int(i/4)]
    def_alpha = [item * mag for item in beta]
    def_beta = [item * mag for item in beta]
    # デフォルト値との差異
    result1 = calc(def_alpha,calpha[i],def_beta,cbeta[i])
    # 予測値との差
    result2 = calc(def_alpha,dalpha[i],def_beta,dbeta[i])
    
    print(str(result2 - result1))
# Out:
# -32.0804323921532
# -27.584013354202508
# -65.80485823089944
# -71.46309187880568
# -595.7846875835423
# -895.0926062734924
# -803.2967465446884
# -741.394250813404
# -2443.6248971318755
# 16281.669482329478
# -2065.7670638602417
# -2587.8110095029424

# %%
# Out:
# 11.0
